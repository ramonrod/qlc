# %%
# %cd /media/Daten/Projects/svn-googlecode/qlc/
sys.path.append("./src")
from qlc.TranslationGraph import write, read
import codecs
# Out:
# /media/Daten/Projects/svn-googlecode/qlc

# %%
g = read(codecs.open("translation_graph_witotoan_proc_singlewords.dot", "r", "utf-8").read())

# %%
import networkx as nx

degree_sequence=sorted(nx.degree(g).values(),reverse=True) # degree sequence
#print "Degree sequence", degree_sequence
dmax=max(degree_sequence)

plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")
plt.show()
